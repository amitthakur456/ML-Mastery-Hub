# %%
# import the necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import cv2

# %%
# load the data 
filedr = cv2.imread(r"C:\Users\asus\Desktop\New folder\Car color Detection")

# %%
import os
file = os.listdir(filedr)
file
# Out:
# ['.ipynb_checkpoints',
#  'added_image.jpg',
#  'Car color Detection',
#  'Lecture 1. Tensorflow.ipynb',
#  'Untitled.ipynb']

# %%
filedr

# %%
train = cv2.imread(r"C:\Users\asus\Desktop\New folder\Car color Detection\train")
test = cv2.imread(r"C:\Users\asus\Desktop\New folder\Car color Detection\test")
val = cv2.imread(r"C:\Users\asus\Desktop\New folder\Car color Detection\val")

# %%
print(train)
# Out:
# None

# %%
print(test)
# Out:
# None

# %%
print(val)
# Out:
# None

# %%
image = cv2.imread(train)

# %%
# Check if the image is loaded properly
if image is not None:
    # Get dimensions
    height, width, channels = image.shape
    print(f"Image Dimensions: {width}x{height} (Width x Height)")
    print(f"Number of Channels: {channels}")
else:
    print("Error: Could not load the image. Check the file path.")
# Out:
# Error: Could not load the image. Check the file path.

# %%
image_path = cv2.imread(r"C:\Users\asus\Desktop\New folder\Car color Detection\train\beige\00ecfeedea.jpg")

# %%
print(image_path)
# Out:
# [[[178 151 124]
#   [179 152 125]
#   [179 152 125]
#   ...
#   [159 136 120]
#   [149 126 110]
#   [144 121 105]]
#
#  [[178 151 124]
#   [176 149 122]
#   [175 148 121]
#   ...
#   [180 157 141]
#   [186 163 147]
#   [190 167 151]]
#
#  [[179 150 123]
#   [181 152 125]
#   [183 154 127]
#   ...
#   [184 161 145]
#   [184 161 145]
#   [185 162 146]]
#
#  ...
#
#  [[ 66  41  25]
#   [ 66  41  25]
#   [ 61  38  22]
#   ...
#   [144 150 149]
#   [179 183 184]
#   [105 109 110]]
#
#  [[ 55  30  14]
#   [ 52  27  11]
#   [ 52  29  13]
#   ...
#   [153 159 158]
#   [129 133 134]
#   [112 116 117]]
#
#  [[ 66  41  25]
#   [ 54  29  13]
#   [ 59  36  20]
#   ...
#   [192 198 197]
#   [103 107 108]
#   [145 149 150]]]

# %%
plt.imshow(image_path)

# %%
image1 = cv2.imread(r"C:\Users\asus\Desktop\New folder\Car color Detection\train\blue\0d89819055.jpg")

# %%
print(image1)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
plt.imshow(image1)

# %%
# checking the dimension of image
height, width, channels = image1.shape
print(f"image shape",{image1.shape})
# Out:
# image shape {(152, 315, 3)}

# %%
# checking the image type from the dataset
if len(image1.shape) == 2:
    print("The image is grayscale.")
elif len(image1.shape) == 3:
    if image1.shape[2] == 3:
        print("The image is color(RGB/BGR) image.")
    elif image1.shape[2] == 4:
        print("The image is a Color image with an Alpha channel (RGBA).")
else:
    print("Error: Could not load the image. Check the file path.")
# Out:
# The image is color(RGB/BGR) image.

# %%
# Rotate the image 
rotated_90 = cv2.rotate(image1,cv2.ROTATE_90_CLOCKWISE)

# %%
plt.imshow(rotated_90)

# %%
rotated_180 = cv2.rotate(image_path, cv2.ROTATE_180)

# %%
print(rotated_180)
# Out:
# [[[145 149 150]
#   [103 107 108]
#   [192 198 197]
#   ...
#   [ 59  36  20]
#   [ 54  29  13]
#   [ 66  41  25]]
#
#  [[112 116 117]
#   [129 133 134]
#   [153 159 158]
#   ...
#   [ 52  29  13]
#   [ 52  27  11]
#   [ 55  30  14]]
#
#  [[105 109 110]
#   [179 183 184]
#   [144 150 149]
#   ...
#   [ 61  38  22]
#   [ 66  41  25]
#   [ 66  41  25]]
#
#  ...
#
#  [[185 162 146]
#   [184 161 145]
#   [184 161 145]
#   ...
#   [183 154 127]
#   [181 152 125]
#   [179 150 123]]
#
#  [[190 167 151]
#   [186 163 147]
#   [180 157 141]
#   ...
#   [175 148 121]
#   [176 149 122]
#   [178 151 124]]
#
#  [[144 121 105]
#   [149 126 110]
#   [159 136 120]
#   ...
#   [179 152 125]
#   [179 152 125]
#   [178 151 124]]]

# %%
plt.imshow(rotated_180)

# %% [markdown]
# # operation on image

# %%
# Print image shape to understand dimensions
print("Image shape:", image_path.shape)  # (height, width, channels)

# Correct cropping (Ensure indices are valid)
cropped_image = image_path[152:315, 3:]  # Crop rows 152 to 315, and all columns from index 3 onward
# Out:
# Image shape: (266, 430, 3)

# %%
# Resize image2 to match image1's shape
image2_resized = cv2.resize(image1, (image1.shape[1], image1.shape[0]))

# %%
print(image2_resized)
# Out:
# [[[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  ...
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]
#
#  [[255 255 255]
#   [255 255 255]
#   [255 255 255]
#   ...
#   [255 255 255]
#   [255 255 255]
#   [255 255 255]]]

# %%
# Now, add the images safely
added_image = cv2.add(image1, image2_resized)

# %%
plt.imshow(added_image)

# %%
# Perform subtraction
sub_image = cv2.subtract(image1, image2_resized)

# %%
plt.imshow(sub_image)

# %%
# Perform element-wise multiplication
multi_image = cv2.multiply(image1, image2_resized)

# %%
plt.imshow(multi_image)
