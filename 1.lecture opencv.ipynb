# %%
import cv2
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# # Plotting

# %%
img1 = cv2.imread(r"C:\Users\asus\Desktop\Gender_Age_Detector\Resources\Nature.2.jpg")

# %%
plt.imshow(img1)

# %%
img2 = cv2.imread(r"C:\Users\asus\Desktop\Gender_Age_Detector\Resources\Nature.jpg")

# %%
plt.imshow(img2)

# %%
# Addition

# %%
img1

# %%
img2

# %%
img1 = cv2.imread(r"C:\Users\asus\Desktop\Gender_Age_Detector\Resources\Nature.2.jpg")
img2 = cv2.imread(r"C:\Users\asus\Desktop\Gender_Age_Detector\Resources\Nature.jpg")
# Crop img2 to match img1
img2_cropped = img2[:img1.shape[0], :img1.shape[1]]

# Now add images
result = cv2.add(img1, img2_cropped)

# %%
plt.imshow(result)

# %%
# Crop img2 to match img1 dimensions
img2_cropped = img2[:img1.shape[0], :img1.shape[1]]

# Perform pixel-wise subtraction
result = cv2.subtract(img1, img2_cropped)

# %%
plt.imshow(result)

# %% [markdown]
# # Multiplication

# %%
# Crop img2 to match img1 dimensions
img2_cropped = img2[:img1.shape[0], :img1.shape[1]]

# Perform pixel-wise subtraction
result = cv2.multiply(img1, img2_cropped)

# %%
plt.imshow(result)

# %% [markdown]
# #Division

# %%
# Crop img2 to match img1 dimensions
img2_cropped = img2[:img1.shape[0], :img1.shape[1]]

# Perform pixel-wise subtraction
result = cv2.divide(img1, img2_cropped)

# %%
plt.imshow(result)

# %% [markdown]
# # Blurring

# %%
img1 = cv2.imread(r"C:\Users\asus\Desktop\Gender_Age_Detector\Resources\Nature.2.jpg")
img = cv2.cvtColor(img1,cv2.COLOR_BGR2RGB)
figure_size = 7
result = cv2.blur(img,(figure_size,figure_size))
plt.figure(figsize = (11,6))
plt.subplot(121),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("Original")
plt.xticks([]),plt.yticks([])
plt.subplot(122),plt.imshow(cv2.cvtColor(img,cv2.COLOR_HSV2RGB)),plt.title("bluring")
plt.xticks([]),plt.yticks([])
plt.show()

# %% [markdown]
# # Zoom

# %%
(height,width) = img1.shape[0:2]
zoom = cv2.resize(img1,None,fx = 1.5,fy = 1.5,interpolation = cv2.INTER_CUBIC)
plt.imshow(zoom)

# %%
zoom = cv2.resize(img1,(int(width*2),int(height*2)), interpolation = cv2.INTER_CUBIC)
plt.imshow(zoom)

# %% [markdown]
# # Rotate

# %%
m = cv2.getRotationMatrix2D((width/2,height/2),30,1)
rotate = cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %%
m = cv2.getRotationMatrix2D((width/2,height/2),45,1)
rotate = cv2.warpAffine(img1,m,(height,width))
plt.imshow(rotate)

# %% [markdown]
# # Translate

# %%
import numpy as np

# %%
m = np.float32([[1,0,50],[0,1,100]])
dst = cv2.warpAffine(img1,m,(height,width))
plt.imshow(dst)
